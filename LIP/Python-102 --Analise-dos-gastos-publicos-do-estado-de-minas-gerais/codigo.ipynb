# %%
import pandas as pd
data = pd.read_excel('./dados/xlsx//consulta_despesas_2020.xlsx')
display(data)
# Out:
#                  Funcao                                              Orgao  \
# 0      DESPORTO E LAZER     SECRETARIA DE ESTADO DE DESENVOLVIMENTO SOCIAL
# 1    ENCARGOS ESPECIAIS  FUNDACAO CENTRO DE HEMATOLOGIA E HEMOTERAPIA D...
# 2    ENCARGOS ESPECIAIS                  FUNDACAO EDUCACIONAL CAIO MARTINS
# 3     SEGURANCA PUBLICA  GABINETE MILITAR DO GOVERNADOR DO ESTADO DE MI...
# 4      GESTAO AMBIENTAL  SECRETARIA DE ESTADO DE MEIO AMBIENTE E DESENV...
# ..                  ...                                                ...
# 289           HABITACAO  PARTICIPACAO NO AUMENTO DO CAPITAL SOCIAL DE E...
# 290               SAUDE     SECRETARIA DE ESTADO DE DESENVOLVIMENTO SOCIAL
# 291          TRANSPORTE  SECRETARIA DE ESTADO DE INFRAESTRUTURA E MOBIL...
# 292            EDUCACAO                           FUNDACAO HELENA ANTIPOFF
# 293               SAUDE  SECRETARIA DE ESTADO DE JUSTICA E SEGURANCA PU...
#
#                                      Subfuncao Valor Empenhado  \
# ...

# %%
pip install plotly
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting plotly
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/a8/07/72953cf70e3bd3a24cbc3e743e6f8539abe6e3e6d83c3c0c83426eaffd39/plotly-5.18.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tenacity>=6.2.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.2/15.6 MB 2.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.5/15.6 MB 4.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.7/15.6 MB 4.7 MB/s eta 0:00:04
#    -- ------------------------------------- 1.1/15.6 MB 5.3 MB/s eta 0:00:03
# ...
